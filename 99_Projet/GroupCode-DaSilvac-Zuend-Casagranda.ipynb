# %% [markdown]
# # Intro

# %% [markdown]
# Ophélie

# %% [markdown]
# # Données

# %% [markdown]
# ## Les données

# %% [markdown]
# Description des données

# %% [markdown]
# Ophélie

# %% [markdown]
# ## Nettoyage

# %% [markdown]
# Explication des étapes de nettoyage

# %% [markdown]
# Brian

# %% [markdown]
# # Modèle Baseline

# %% [markdown]
# ## Le modèle

# %% [markdown]
# Brian

# %% [markdown]
# ## Paramètres

# %% [markdown]
# Brian

# %% [markdown]
# ## Résultat

# %% [markdown]
# Brian
#
# -> A vérifier mais je dirais que pour chaque résultat il faut comparer en se basant sur RMSLE

# %% [markdown]
# # Modèle 1

# %% [markdown]
# Finir modèle 1 Ophé Marino

# %% [markdown]
# ## Le modèle

# %% [markdown]
# ## Les paramètres

# %% [markdown]
# Itération 1

# %% [markdown]
# Itération 2

# %% [markdown]
# ## Hyparamètres

# %% [markdown]
# Itération 1

# %% [markdown]
# Itération 2

# %% [markdown]
# ## Entraînement

# %% [markdown]
# ## Le résultat

# %% [markdown]
# Itération 1

# %% [markdown]
# Itération 2

# %% [markdown]
# # Modèle 2

# %% [markdown]
# ## Le modèle

# %% [markdown]
# ## Les paramètres

# %% [markdown]
# Itération 1

# %% [markdown]
# Itération 2

# %% [markdown]
# ## Hyparamètres

# %% [markdown]
# Itération 1

# %% [markdown]
# Itération 2

# %% [markdown]
# ## Entraînement

# %% [markdown]
# ## Le résultat

# %% [markdown]
# Itération 1

# %% [markdown]
# Itération 2

# %% [markdown]
# # Conclusion

# %% [markdown]
# Ophélie

# %% [markdown]
# ## Éthique
